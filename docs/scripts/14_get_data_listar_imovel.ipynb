# %% [markdown]
# <br>
#
# # Imóveis
#
#
# Por meio do _site_ [ListaTelefonica](https://www.tjsp.jus.br/ListaTelefonica) foi possível relevar as APIs que operam e fazer diversas pesquisas.
#
# <br>
#
# Michel Metran\
# Data: 18.06.2024\
# Atualizado em: 18.06.2024

# %%
from tjsp_unidades import extract
from tjsp_unidades.paths import output_path_tab

# %%
import pprint
import re

import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# <br>
#
# ---
#
# ## Lista de Imóveis

# %% [markdown]
# <br>
#
# ---
#
# ### Municípios
#
# Inicialmente se faz necessário listar de imóveis, que está na tabela de detalhes dos municípios.

# %%
# Listar Unidades
municipio = extract.Municipio()
municipio.search_batch()
municipio.detalhe_batch()
# Out:
# São 4267 termos para pesquisa
#       id_municipio_tjsp                           raj          municipio_tjsp  \
# 0                  6505  8ª RAJ São José do Rio Preto                  Adolfo
# 1                  6505  8ª RAJ São José do Rio Preto                  Adolfo
# 2                  6507               4ª RAJ Campinas          Águas da Prata
# 3                  6507               4ª RAJ Campinas          Águas da Prata
# 4                  6516              2ª RAJ Araçatuba             Alto Alegre
# ...                 ...                           ...                     ...
# 1305               7139    5ª RAJ Presidente Prudente               Vera Cruz
# 1306               7137       1ª RAJ Grande São Paulo  Vargem Grande Paulista
# 1307               7140               4ª RAJ Campinas                 Vinhedo
# 1308               7140               4ª RAJ Campinas                 Vinhedo
# 1309               7140               4ª RAJ Campinas                 Vinhedo
#
#                 comarca_tjsp  comarca_sede  \
# 0             José Bonifácio             0
# 1             José Bonifácio             0
# 2      São João da Boa Vista             0
# 3      São João da Boa Vista             0
# 4                  Penápolis             0
# ...                      ...           ...
# 1305                 Marília             0
# 1306  Vargem Grande Paulista             1
# 1307                 Vinhedo             1
# 1308                 Vinhedo             1
# 1309                 Vinhedo             1
#
#                                                  imovel
# 0                    Fórum José Bonifácio - II (CEJUSC)
# 1                    Fórum José Bonifácio I (Principal)
# 2     Cartório Anexo do Juizado Especial Cível - UNI...
# 3                            Fórum I Dr. Plínio Barreto
# 4                                   Fórum Penápolis I -
# ...                                                 ...
# 1305                          Fórum Marília IV (CEJUSC)
# 1306              Desembargador HELIO DE QUADROS ARRUDA
# 1307                             Fórum Juiz João Mendes
# 1308                 Fórum Vinhedo II - Execução Fiscal
# 1309                         Fórum Vinhedo III - CEJUSC
#
# [1306 rows x 6 columns]

# %% [markdown]
# <br>
#
# Uma vez com a função que obter os dados das Unidades e, PRINCIPALMENTE, obter as comarcas!
# Foi possível iterar pelos 645 municípios para pegar as informações dos imóveis.

# %% [markdown]
# <br>
#
# ---
#
# ### Imóveis

# %%
imovel = extract.Imovel(municipio=municipio)

# %% [markdown]
# <br>
#
# Uma vez com a lista de todos os municípios e seus respectivos códigos, foi possível obter as informações dos fóruns por meio de outro método `POST`.

# %%
imovel.search(termo='forum')
# Out:
#    id_imovel                                        imovel_tjsp
# 3          3                             Fórum Águas de Lindóia
# 5          4                                       Fórum Agudos
# 6          5                                  Fórum Altinópolis
# 7          6                                    Fórum Americana
# 9          7                          Fórum Américo Brasiliense
# 1        172      Fórum "Juiz Eleutério Dutra Filho" - Mongaguá
# 2        245  Fórum "Juiz Messias José de Melo Souza" (Sales...
# 4        415      Fórum Águas de Lindóia (J.E.CÍVEL e Criminal)
# 0        435         ANEXO FISCAL - Fórum Santa Bárbara d´Oeste
# 8        631                  Fórum Americana (CEJUSC) - UNISAL

# %% [markdown]
# <br>
#
# Há também alguns métodos privados
#
# ```python
# imovel._n_caracteres_mun_max
# imovel._list_termos
# ```

# %%
imovel.search_batch()

# Results
imovel.df_search.info()
imovel.df_search.head()
# Out:
# São 3192 termos para pesquisa
# <class 'pandas.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id_imovel    640 non-null    int64
#  1   imovel_tjsp  640 non-null    str
# dtypes: int64(1), str(1)
# memory usage: 10.1 KB
#    id_imovel             imovel_tjsp
# 0          1      Fórum I Adamantina
# 1          2          Fórum de Aguaí
# 2          3  Fórum Águas de Lindóia
# 3          4            Fórum Agudos
# 4          5       Fórum Altinópolis

# %% [markdown]
# <br>
#
# Pesquisa de um imóvel qualquer

# %%
mask = imovel.df_search["id_imovel"] == 240
imovel.df_search[mask]["imovel_tjsp"].values
# Out:
# <StringArray>
# ['Tribunal de Justiça da Comarca de Ribeirão Preto - Prédio I']
# Length: 1, dtype: str

# %% [markdown]
# <br>
#
# ---
#
# ## Detalhes
#
# É possível consultar detalhes de um imóvel

# %%
id_imovel = 291

# %%
imovel.detalhe(id_imovel=id_imovel)
# Out:
#    id_imovel                imovel  \
# 0        291  Fórum Taquaritinga I
#
#                                             endereco         telefone  \
# 0  Rua Duque de Caxias , 267 - Centro - CEP 15900...  (16) 3253-9840;
#
#              fax                        email           cj  \
# 0  Não Informado  taquaritingaadm@tjsp.jus.br  Jaboticabal
#
#   num_varas_instaladas          entrancia  comarca_tjsp dist_capital  \
# 0                    4  Entrância Inicial  Taquaritinga    305.93 Km
#
#   tensao_eletrica
# 0            110V

# %% [markdown]
# <br>
#
# O método `obter_imovel` reflete um _endpoint_ do TJSP que é público. Contudo, ao que tudo indicada, ele retorna o mesmo que o método `detalhe`.

# %%
imovel.obter_imovel(id_imovel=id_imovel)
# Out:
#    id_imovel                imovel  \
# 0        291  Fórum Taquaritinga I
#
#                                             endereco         telefone  \
# 0  Rua Duque de Caxias , 267 - Centro - CEP 15900...  (16) 3253-9840;
#
#              fax                        email           cj  \
# 0  Não Informado  taquaritingaadm@tjsp.jus.br  Jaboticabal
#
#   num_varas_instaladas          entrancia  comarca_tjsp dist_capital  \
# 0                    4  Entrância Inicial  Taquaritinga    305.93 Km
#
#   tensao_eletrica
# 0            110V

# %% [markdown]
# <br>
#
# E é possível fazer isso em modo _batch_, ou seja, pesquisando **em lote**. Para esse método eu, inicialmente, usava parte do nome das unidades (que obtive juntamente com os municípios), para pesquisar. Observei que nem todos os imóveis eram mapeados com esse método, dai "chumbei" no código a iteração entre 0 e 1200.

# %%
imovel.detalhe_batch()
# Out:
#      id_imovel                                             imovel  \
# 0            1                                 Fórum I Adamantina
# 1            2                                   Comarca de Aguaí
# 2            3                             Fórum Águas de Lindóia
# 3            4  FÓRUM DESEMBARGADOR "FRANCISCO MEIRELLES DOS S...
# 4            5        Fórum "Desembargador ALFREDO FANUCCHI NETO"
# ..         ...                                                ...
# 913        968  Fórum Francisco Morato V - CEJUSC (Defensoria ...
# 914        969  Fórum da Barra Funda - Anexo da Infância e da ...
# 915        970                             Mairiporâ III - CEJUSC
# 916        971                      CEJUSC II – UAAJ UNIGUARULHOS
# 917        972  Fórum Bauru - UPJ 1ª E 2ª VARAS DE VIOLÊNCIA D...
#
#            telefone            fax                        email  \
# 0    (18) 2106-1718  Não Informado    adamantinaadm@tjsp.jus.br
# 1     Não Informado  Não Informado         aguaiadm@tjsp.jus.br
# 2    (19) 2154-5204  Não Informado  aguaslindoiaadm@tjsp.jus.br
# 3    (14) 2151-5455  Não Informado        agudosadm@tjsp.jus.br
# 4    (16) 3665-2211  Não Informado       altinopadm@tjsp.jus.br
# ..              ...            ...                          ...
# 913  (11) 4489-8701  Não Informado                Não Informado
# 914   Não Informado  Não Informado                Não Informado
# 915  (11) 4419-1820  Não Informado                Não Informado
# 916   Não Informado  Não Informado                Não Informado
# 917   Não Informado  Não Informado                Não Informado
#
#                         cj  num_varas_instaladas          entrancia  \
# 0                     Tupã                     3  Entrância Inicial
# 1    São João da Boa Vista                     1  Entrância Inicial
# 2                   Amparo                     1  Entrância Inicial
# 3                    Bauru                     2  Entrância Inicial
# 4                 Batatais                     1  Entrância Inicial
# ..                     ...                   ...                ...
# 913                Jundiaí                     0    Entrância Final
# 914              São Paulo                     5      Não Informado
# 915              Guarulhos                     0  Entrância Inicial
# 916              Guarulhos                     0    Entrância Final
# 917                  Bauru                     2    Entrância Final
#
#          comarca_tjsp  dist_capital tensao_eletrica  \
# 0          Adamantina        500.26            110V
# 1               Aguaí        169.25            110V
# 2    Águas de Lindóia        119.20            110V
# 3              Agudos        268.95            110V
# 4         Altinópolis        290.52            110V
# ..                ...           ...             ...
# 913  Francisco Morato         31.60            110V
# 914         São Paulo          0.00            110V
# 915         Mairiporã         25.95            110V
# 916         Guarulhos         14.13            110V
# 917             Bauru        283.65            110V
#
#                                   endereco_lougradouro endereco_cep  \
# 0              Avenida Ademar de Barros , 133 - Centro    17800-000
# 1       Rua Joaquim Paula Cruz , 900 - Jd. Sta. Úrsula    13863-044
# 2         Rua Francisco Spartani , 66 - Jd. Le Villete    13940-000
# 3               Rua Paulo Nelli , 276 - Vila Andreotti    17120-370
# 4     Avenida Doutor Alberto Crivelenti , 555 - Centro    14350-005
# ..                                                 ...          ...
# 913                       Rua Progresso , 110 - Centro    07910-170
# 914  Rua José Gomes Falcão , 156 - Portão F - Barra...    01139-010
# 915             Alameda Tibiriçá , 1103 - Vila Ipanema    07600-084
# 916                Praça Tereza Cristina , 88 - Centro    07023-070
# 917               Rua Silva Jardim , 2-77 - Bela Vista    17060-240
#
#     endereco_municipio endereco_uf
# 0           Adamantina          SP
# 1                Aguaí          SP
# 2     Águas de Lindóia          SP
# 3               Agudos          SP
# 4          Altinópolis          SP
# ..                 ...         ...
# 913   Francisco Morato          SP
# 914          São Paulo          SP
# 915          Mairiporã          SP
# 916          Guarulhos          SP
# 917              Bauru          SP
#
# [918 rows x 15 columns]

# %% [markdown]
# <br>
#
# Com isso chegamos à 321 comarcas. Acredito que o erro da Vila Mimosa esteja também aqui.

# %%
len(set(imovel.df_detalhes['comarca_tjsp']))
# Out:
# 321

# %% [markdown]
# <br>
#
# Não está!

# %%
mask = imovel.df_detalhes['comarca_tjsp'].str.contains('Vila')
imovel.df_detalhes[mask]
# Out:
# Empty DataFrame
# Columns: [id_imovel, imovel, telefone, fax, email, cj, num_varas_instaladas, entrancia, comarca_tjsp, dist_capital, tensao_eletrica, endereco_lougradouro, endereco_cep, endereco_municipio, endereco_uf]
# Index: []

# %% [markdown]
# <br>
#
# Salvamos o resultado.

# %%
imovel.df_detalhes.to_csv(
    path_or_buf=output_path_tab / "imovel.csv",
    index=False,
)

# %%
df_detalhes = imovel.df_detalhes.copy()
df_detalhes.info()
df_detalhes.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id_imovel             918 non-null    int64
#  1   imovel                918 non-null    str
#  2   telefone              918 non-null    str
#  3   fax                   918 non-null    str
#  4   email                 918 non-null    str
#  5   cj                    918 non-null    str
#  6   num_varas_instaladas  918 non-null    int64
#  7   entrancia             918 non-null    str
#  8   comarca_tjsp          918 non-null    str
#  9   dist_capital          675 non-null    float64
#  10  tensao_eletrica       918 non-null    str
#  11  endereco_lougradouro  918 non-null    str
#  12  endereco_cep          918 non-null    str
#  13  endereco_municipio    918 non-null    str
#  14  endereco_uf           918 non-null    str
# dtypes: float64(1), int64(2), str(12)
# memory usage: 107.7 KB
#    id_imovel                                             imovel  \
# 0          1                                 Fórum I Adamantina
# 1          2                                   Comarca de Aguaí
# 2          3                             Fórum Águas de Lindóia
# 3          4  FÓRUM DESEMBARGADOR "FRANCISCO MEIRELLES DOS S...
# 4          5        Fórum "Desembargador ALFREDO FANUCCHI NETO"
#
#          telefone            fax                        email  \
# 0  (18) 2106-1718  Não Informado    adamantinaadm@tjsp.jus.br
# 1   Não Informado  Não Informado         aguaiadm@tjsp.jus.br
# 2  (19) 2154-5204  Não Informado  aguaslindoiaadm@tjsp.jus.br
# 3  (14) 2151-5455  Não Informado        agudosadm@tjsp.jus.br
# 4  (16) 3665-2211  Não Informado       altinopadm@tjsp.jus.br
#
#                       cj  num_varas_instaladas          entrancia  \
# 0                   Tupã                     3  Entrância Inicial
# 1  São João da Boa Vista                     1  Entrância Inicial
# 2                 Amparo                     1  Entrância Inicial
# 3                  Bauru                     2  Entrância Inicial
# 4               Batatais                     1  Entrância Inicial
#
#        comarca_tjsp  dist_capital tensao_eletrica  \
# 0        Adamantina        500.26            110V
# 1             Aguaí        169.25            110V
# 2  Águas de Lindóia        119.20            110V
# 3            Agudos        268.95            110V
# 4       Altinópolis        290.52            110V
#
#                                endereco_lougradouro endereco_cep  \
# 0           Avenida Ademar de Barros , 133 - Centro    17800-000
# 1    Rua Joaquim Paula Cruz , 900 - Jd. Sta. Úrsula    13863-044
# 2      Rua Francisco Spartani , 66 - Jd. Le Villete    13940-000
# 3            Rua Paulo Nelli , 276 - Vila Andreotti    17120-370
# 4  Avenida Doutor Alberto Crivelenti , 555 - Centro    14350-005
#
#   endereco_municipio endereco_uf
# 0         Adamantina          SP
# 1              Aguaí          SP
# 2   Águas de Lindóia          SP
# 3             Agudos          SP
# 4        Altinópolis          SP
