# %% [markdown]
# <br>
#
# # Imóveis
#
#
# Por meio do _site_ [ListaTelefonica](https://www.tjsp.jus.br/ListaTelefonica) foi possível relevar as APIs que operam e fazer diversas pesquisas.
#
# <br>
#
# Michel Metran\
# Data: 18.06.2024\
# Atualizado em: 18.06.2024

# %%
from tjsp_unidades import extract
from tjsp_unidades.paths import output_path_tab

# %%
import pprint
import re

import pandas as pd
from bs4 import BeautifulSoup

# %% [markdown]
# <br>
#
# ---
#
# ## Lista de Imóveis

# %% [markdown]
# <br>
#
# ---
#
# ### Municípios
#
# Inicialmente se faz necessário listar de imóveis, que está na tabela de detalhes dos municípios.

# %%
# Listar Unidades
municipio = extract.Municipio()
municipio.search_batch()
municipio.detalhe_batch()
# Out:
# São 4267 termos para pesquisa
# Erro ao processar o termo 'General Salg': HTTPSConnectionPool(host='www.tjsp.jus.br', port=443): Read timed out. (read timeout=60)
# Erro ao processar o termo 'Dum': HTTPSConnectionPool(host='www.tjsp.jus.br', port=443): Read timed out. (read timeout=60)
# Erro ao processar o termo 'Engenheiro': HTTPSConnectionPool(host='www.tjsp.jus.br', port=443): Read timed out. (read timeout=60)
# Erro ao processar o termo 'Presidente Berna': HTTPSConnectionPool(host='www.tjsp.jus.br', port=443): Read timed out. (read timeout=60)
# Erro ao processar o termo 'Santa Adéli': HTTPSConnectionPool(host='www.tjsp.jus.br', port=443): Read timed out. (read timeout=60)
# Erro ao processar o termo 'Promissã': HTTPSConnectionPool(host='www.tjsp.jus.br', port=443): Read timed out. (read timeout=60)
# Erro ao processar o termo 'Santa Fé do Su': HTTPSConnectionPool(host='www.tjsp.jus.br', port=443): Read timed out. (read timeout=60)
# Erro ao processar o termo 'Estrela do Nor': HTTPSConnectionPool(host='www.tjsp.jus.br', port=443): Read timed out. (read timeout=60)
# Erro ao processar o termo 'Miracat': HTTPSConnectionPool(host='www.tjsp.jus.br', port=443): Read timed out. (read timeout=60)
# Erro ao processar o termo 'Rio Cl': HTTPSConnectionPool(host='www.tjsp.jus.br', port=443): Read timed out. (read timeout=60)
# Erro ao processar o termo 'Sumar': HTTPSConnectionPool(host='www.tjsp.jus.br', port=443): Read timed out. (read timeout=60)
# Erro ao processar o termo 'Hortolân': HTTPSConnectionPool(host='www.tjsp.jus.br', port=443): Read timed out. (read timeout=60)
#       id_municipio_tjsp                         raj       municipio_tjsp  \
# 0                  6527            2ª RAJ Araçatuba            Andradina
# 1                  6527            2ª RAJ Araçatuba            Andradina
# 2                  6527            2ª RAJ Araçatuba            Andradina
# 3                  6521  5ª RAJ Presidente Prudente          Alvinlândia
# 4                  6521  5ª RAJ Presidente Prudente          Alvinlândia
# ...                 ...                         ...                  ...
# 1305               6535            2ª RAJ Araçatuba            Araçatuba
# 1306               6535            2ª RAJ Araçatuba            Araçatuba
# 1307               6510             4ª RAJ Campinas   Águas de São Pedro
# 1308               6523       6ª RAJ Ribeirão Preto  Américo Brasiliense
# 1309               6534            10ª RAJ Sorocaba         Araçariguama
#
#              comarca_tjsp  comarca_sede  \
# 0               Andradina             1
# 1               Andradina             1
# 2               Andradina             1
# 3                   Garça             0
# 4                   Garça             0
# ...                   ...           ...
# 1305            Araçatuba             1
# 1306            Araçatuba             1
# 1307            São Pedro             0
# 1308  Américo Brasiliense             1
# 1309            São Roque             0
#
#                                                  imovel
# 0            Fórum Andradina I (Homero Rodrigues Silva)
# 1     Fórum Andradina III - Anexo de Violência Domés...
# 2     Fórum Andradina V - Anexo do Juizado de Andrad...
# 3                                         Fórum I Garça
# 4                               Fórum II Garça (CEJUSC)
# ...                                                 ...
# 1305                      Fórum Araçatuba I - PRINCIPAL
# 1306  Forum Araçatuba V - Serviço de Atendimento Psi...
# 1307                 Fórum "Francisco Mendes de Aguiar"
# 1308                          Fórum Américo Brasiliense
# 1309                                  Fórum São Roque I
#
# [1306 rows x 6 columns]

# %% [markdown]
# <br>
#
# Uma vez com a função que obter os dados das Unidades e, PRINCIPALMENTE, obter as comarcas!
# Foi possível iterar pelos 645 municípios para pegar as informações dos imóveis.

# %% [markdown]
# <br>
#
# ---
#
# ### Imóveis

# %%
imovel = extract.Imovel(municipio=municipio)

# %% [markdown]
# <br>
#
# Uma vez com a lista de todos os municípios e seus respectivos códigos, foi possível obter as informações dos fóruns por meio de outro método `POST`.

# %%
imovel.search(termo='forum')
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# File d:\Codes\GitHub\Personal\my_projects\tjsp_unidades\.venv\Lib\site-packages\urllib3\connectionpool.py:788, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 # Make the request on the HTTPConnection object
# --> 788 response = self._make_request(
#     789     conn,
#     790     method,
#     791     url,
#     792     timeout=timeout_obj,
#     793     body=body,
#     794     headers=headers,
#     795     chunked=chunked,
#     796     retries=retries,
#     797     response_conn=response_conn,
#     798     preload_content=preload_content,
#     799     decode_content=decode_content,
#     800     **response_kw,
#     801 )
#     803 # Everything went great!
#
# File d:\Codes\GitHub\Personal\my_projects\tjsp_unidades\.venv\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File d:\Codes\GitHub\Personal\my_projects\tjsp_unidades\.venv\Lib\site-packages\urllib3\connection.py:571, in HTTPConnection.getresponse(self)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\http\client.py:1450, in HTTPConnection.getresponse(self)
#    1449 try:
# -> 1450     response.begin()
#    1451 except ConnectionError:
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\http\client.py:336, in HTTPResponse.begin(self)
#     335 while True:
# --> 336     version, status, reason = self._read_status()
#     337     if status != CONTINUE:
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\http\client.py:305, in HTTPResponse._read_status(self)
#     302 if not line:
#     303     # Presumably, the server closed the connection before
#     304     # sending a valid response.
# --> 305     raise RemoteDisconnected("Remote end closed connection without"
#     306                              " response")
#     307 try:
#
# RemoteDisconnected: Remote end closed connection without response
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File d:\Codes\GitHub\Personal\my_projects\tjsp_unidades\.venv\Lib\site-packages\requests\adapters.py:696, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     695 try:
# --> 696     resp = conn.urlopen(
#     697         method=request.method,
#     698         url=url,
#     699         body=request.body,  # type: ignore[arg-type]  # urllib3 stubs don't accept Iterable[bytes | str]
#     700         headers=request.headers,  # type: ignore[arg-type]  # urllib3#3072
#     701         redirect=False,
#     702         assert_same_host=False,
#     703         preload_content=False,
#     704         decode_content=False,
#     705         retries=self.max_retries,
#     706         timeout=resolved_timeout,
#     707         chunked=chunked,
#     708     )
#     710 except (ProtocolError, OSError) as err:
#
# File d:\Codes\GitHub\Personal\my_projects\tjsp_unidades\.venv\Lib\site-packages\urllib3\connectionpool.py:842, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     840     new_e = ProtocolError("Connection aborted.", new_e)
# --> 842 retries = retries.increment(
#     843     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     844 )
#     845 retries.sleep()
#
# File d:\Codes\GitHub\Personal\my_projects\tjsp_unidades\.venv\Lib\site-packages\urllib3\util\retry.py:498, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     497 if read is False or method is None or not self._is_method_retryable(method):
# --> 498     raise reraise(type(error), error, _stacktrace)
#     499 elif read is not None:
#
# File d:\Codes\GitHub\Personal\my_projects\tjsp_unidades\.venv\Lib\site-packages\urllib3\util\util.py:38, in reraise(tp, value, tb)
#      37 if value.__traceback__ is not tb:
# ---> 38     raise value.with_traceback(tb)
#      39 raise value
#
# File d:\Codes\GitHub\Personal\my_projects\tjsp_unidades\.venv\Lib\site-packages\urllib3\connectionpool.py:788, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 # Make the request on the HTTPConnection object
# --> 788 response = self._make_request(
#     789     conn,
#     790     method,
#     791     url,
#     792     timeout=timeout_obj,
#     793     body=body,
#     794     headers=headers,
#     795     chunked=chunked,
#     796     retries=retries,
#     797     response_conn=response_conn,
#     798     preload_content=preload_content,
#     799     decode_content=decode_content,
#     800     **response_kw,
#     801 )
#     803 # Everything went great!
#
# File d:\Codes\GitHub\Personal\my_projects\tjsp_unidades\.venv\Lib\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#
# File d:\Codes\GitHub\Personal\my_projects\tjsp_unidades\.venv\Lib\site-packages\urllib3\connection.py:571, in HTTPConnection.getresponse(self)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\http\client.py:1450, in HTTPConnection.getresponse(self)
#    1449 try:
# -> 1450     response.begin()
#    1451 except ConnectionError:
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\http\client.py:336, in HTTPResponse.begin(self)
#     335 while True:
# --> 336     version, status, reason = self._read_status()
#     337     if status != CONTINUE:
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\http\client.py:305, in HTTPResponse._read_status(self)
#     302 if not line:
#     303     # Presumably, the server closed the connection before
#     304     # sending a valid response.
# --> 305     raise RemoteDisconnected("Remote end closed connection without"
#     306                              " response")
#     307 try:
#
# ProtocolError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 imovel.search(termo='forum')
#
# File D:\Codes\GitHub\Personal\my_projects\tjsp_unidades\tjsp_unidades\extract\api_imovel.py:35, in Imovel.search(self, termo)
#      31 # Requests
#      32 # Create Session
#      33 session = get_session()
# ---> 35 r = session.post(
#      36     "https://www.tjsp.jus.br/AutoComplete/ListarImoveis",
#      37     json={"texto": termo},
#      38     timeout=60,
#      39 )
#      40 if r.json() == "listaVazia":
#      41     return pd.DataFrame()
#
# File d:\Codes\GitHub\Personal\my_projects\tjsp_unidades\.venv\Lib\site-packages\requests\sessions.py:712, in Session.post(self, url, data, json, **kwargs)
#     695 def post(
#     696     self,
#     697     url: _t.UriType,
#    (...)    700     **kwargs: Unpack[_t.PostKwargs],
#     701 ) -> Response:
#     702     r"""Sends a POST request. Returns :class:`Response` object.
#     703
#     704     :param url: URL for the new :class:`Request` object.
#    (...)    709     :rtype: requests.Response
#     710     """
# --> 712     return self.request("POST", url, data=data, json=json, **kwargs)
#
# File d:\Codes\GitHub\Personal\my_projects\tjsp_unidades\.venv\Lib\site-packages\requests\sessions.py:651, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     646 send_kwargs = {
#     647     "timeout": timeout,
#     648     "allow_redirects": allow_redirects,
#     649 }
#     650 send_kwargs.update(settings)
# --> 651 resp = self.send(prep, **send_kwargs)
#     653 return resp
#
# File d:\Codes\GitHub\Personal\my_projects\tjsp_unidades\.venv\Lib\site-packages\requests\sessions.py:784, in Session.send(self, request, **kwargs)
#     781 start = preferred_clock()
#     783 # Send the request
# --> 784 r = adapter.send(request, **kwargs)
#     786 # Total elapsed time of the request (approximately)
#     787 elapsed = preferred_clock() - start
#
# File d:\Codes\GitHub\Personal\my_projects\tjsp_unidades\.venv\Lib\site-packages\requests\adapters.py:711, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     696     resp = conn.urlopen(
#     697         method=request.method,
#     698         url=url,
#    (...)    707         chunked=chunked,
#     708     )
#     710 except (ProtocolError, OSError) as err:
# --> 711     raise ConnectionError(err, request=request)
#     713 except MaxRetryError as e:
#     714     if isinstance(e.reason, ConnectTimeoutError):
#     715         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))

# %% [markdown]
# <br>
#
# Há também alguns métodos privados
#
# ```python
# imovel._n_caracteres_mun_max
# imovel._list_termos
# ```

# %%
imovel.search_batch()

# Results
imovel.df_search.info()
imovel.df_search.head()

# %% [markdown]
# <br>
#
# Pesquisa de um imóvel qualquer

# %%
mask = imovel.df_search["id_imovel"] == 240
imovel.df_search[mask]["imovel_tjsp"].values

# %% [markdown]
# <br>
#
# ---
#
# ## Detalhes
#
# É possível consultar detalhes de um imóvel

# %%
id_imovel = 291

# %%
imovel.detalhe(id_imovel=id_imovel)

# %% [markdown]
# <br>
#
# O método `obter_imovel` reflete um _endpoint_ do TJSP que é público. Contudo, ao que tudo indicada, ele retorna o mesmo que o método `detalhe`.

# %%
imovel.obter_imovel(id_imovel=id_imovel)

# %% [markdown]
# <br>
#
# E é possível fazer isso em modo _batch_, ou seja, pesquisando **em lote**. Para esse método eu, inicialmente, usava parte do nome das unidades (que obtive juntamente com os municípios), para pesquisar. Observei que nem todos os imóveis eram mapeados com esse método, dai "chumbei" no código a iteração entre 0 e 1200.

# %%
imovel.detalhe_batch()

# %% [markdown]
# <br>
#
# Com isso chegamos à 321 comarcas. Acredito que o erro da Vila Mimosa esteja também aqui.

# %%
len(set(imovel.df_detalhes['comarca_tjsp']))

# %% [markdown]
# <br>
#
# Não está!

# %%
mask = imovel.df_detalhes['comarca_tjsp'].str.contains('Vila')
imovel.df_detalhes[mask]

# %% [markdown]
# <br>
#
# Salvamos o resultado.

# %%
imovel.df_detalhes.to_csv(
    path_or_buf=output_path_tab / "imovel.csv",
    index=False,
)

# %%
df_detalhes = imovel.df_detalhes.copy()
df_detalhes.info()
df_detalhes.head()
