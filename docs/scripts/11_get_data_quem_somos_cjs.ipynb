# %% [markdown]
# <br>
#
# # Circunscrição Judiciária
#
# Por meio do _site_ [Quem Somos](https://www.tjsp.jus.br/QuemSomos/QuemSomos/RegioesAdministrativasJudiciarias) obtenho as informações das _Regiões Administrativas Judiciárias_.

# %%
from tjsp_unidades import extract
from tjsp_unidades.paths import output_path_tab

# %%
quem_somos = extract.QuemSomos()

# %% [markdown]
# <br>
#
# ---
#
# ## CJs
#
# Obtenhos dados de _Circunscrições Judiciárias_ e relaciono isso com as RAJs.

# %%
df_cj = quem_somos.cjs

df_cj.head()
# Out:
#    id_cj cj_sigla                      cj_nome  id_raj
# 0      0  Capital                      Capital       1
# 1      1    1ª CJ  1ª Circunscrição Judiciária       7
# 2      2    2ª CJ  2ª Circunscrição Judiciária       1
# 3      3    3ª CJ  3ª Circunscrição Judiciária       1
# 4      4    4ª CJ  4ª Circunscrição Judiciária       1

# %%
df_cj.to_csv(
    path_or_buf=output_path_tab / "cjs.csv",
    index=False,
)
