# %% [markdown]
# <br>
#
# # Comarcas
#
# Por meio do _site_ [Quem Somos](https://www.tjsp.jus.br/QuemSomos/QuemSomos/RegioesAdministrativasJudiciarias) obtenho as informações das _Regiões Administrativas Judiciárias_.

# %%
from tjsp_unidades import extract
from tjsp_unidades.paths import output_path_tab

# %%
quem_somos = extract.QuemSomos()

# %% [markdown]
# <br>
#
# ---
#
# ## Comarcas
#
# Obtemos os dados de Comarcas por CJ.

# %%
df_comarca = quem_somos.comarcas

# Results
df_comarca.info()
df_comarca.head()
# Out:
# São 321 comarcas
# <class 'pandas.DataFrame'>
# RangeIndex: 321 entries, 0 to 320
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   comarca_tjsp  321 non-null    str
#  1   id_cj         321 non-null    int64
# dtypes: int64(1), str(1)
# memory usage: 5.1 KB
#   comarca_tjsp  id_cj
# 0   Adamantina     30
# 1        Aguaí     50
# 2       Agudos     32
# 3  Altinópolis     39
# 4    Americana     53

# %%
filename = "cjs_comarcas"

df_comarca.to_csv(
    path_or_buf=output_path_tab / f"{filename}.csv",
    index=False,
)
