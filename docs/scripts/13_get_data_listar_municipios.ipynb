# %% [markdown]
# <br>
#
# # Municípios
#
# Explorando o _site_ [ListaTelefonica](https://www.tjsp.jus.br/ListaTelefonica) foi possível encontrar APIs que operam e fazer diversas pesquisas.

# %%
from tjsp_unidades import extract
from tjsp_unidades.paths import output_path_tab

# %% [markdown]
# <br>
#
# ---
#
# ## Lista de Municípios

# %% [markdown]
# Criamos função que pega o Nome e Código do município, de acordo com o TJSP.

# %%
municipio = extract.Municipio()

# %%
# Apenas Exemplo da Função!
municipio.search(termo='San')
# Out:
#    id_municipio_tjsp            municipio_tjsp
# 0               6509    Águas de Santa Bárbara
# 1               6675  Espírito Santo do Pinhal
# 2               6676   Espírito Santo do Turvo
# 3               6892            Oscar Bressane
# 4               7000                    Rosana
# 5               7014               Sandovalina
# 6               7015              Santa Adélia
# 7               7016           Santa Albertina
# 8               7017     Santa Bárbara d'Oeste
# 9               7018              Santa Branca

# %% [markdown]
# Para termos um _input_ para a função, que é necessário inserir um termo para pesquisa.
#
# Para obter diveresos termos, usei o nomes dos municípios que constam no projeto [open_geodata]().

# %%
municipio._lista_municipios[0:5]
# Out:
# ['Adamantina', 'Adolfo', 'Aguaí', 'Águas da Prata', 'Águas de Lindóia']

# %% [markdown]
# <br>
#
# Obtive o município com maior número de caracteres, visto que a função do método `POST` sempre lista apenas 10 municípios...

# %%
municipio._n_caracteres_mun_max
# Out:
# 26

# %% [markdown]
# <br>
#
# Uma vez com a função que retorna os municípios escrita, fiz uma iteração por todos os trechos de nomes de municípios. Para cada municípios foi pesquisado diversas vezes, incrementando o número de caracteres. Por exemplos, o município de Santos foi pesquisado:
#
# - San
# - Sant
# - Santo
# - Santos
#
# <br>
#
# Isso garantiu que todos os municípios foram "raspados".

# %%
municipio._list_termos[0:5]
# Out:
# São 4267 termos para pesquisa
# ['Adolf', 'Campo', 'Drac', 'Poti', 'São Vicen']

# %% [markdown]
# <br>
#
# Antes eu levava cerca de 40 minutos para rodar. Ajustando o código, passei a levar 40 segundos.

# %%
# Obtem todos os IDs dos Municípios do TJSP
municipio.search_batch()

# Results
municipio.df_search.info()
municipio.df_search.head()
# Out:
# São 4267 termos para pesquisa
# <class 'pandas.DataFrame'>
# RangeIndex: 645 entries, 0 to 644
# Data columns (total 4 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   id_municipio_ibge         645 non-null    int64
#  1   id_municipio_tjsp         645 non-null    int64
#  2   municipio_tjsp            645 non-null    str
#  3   municipio_tjsp_corrigido  645 non-null    str
# dtypes: int64(2), str(2)
# memory usage: 20.3 KB
#    id_municipio_ibge  id_municipio_tjsp    municipio_tjsp  \
# 0            3500105               6504        Adamantina
# 1            3500204               6505            Adolfo
# 2            3500303               6506             Aguaí
# 3            3500402               6507    Águas da Prata
# 4            3500501               6508  Águas de Lindóia
#
#   municipio_tjsp_corrigido
# 0               Adamantina
# 1                   Adolfo
# 2                    Aguaí
# 3           Águas da Prata
# 4         Águas de Lindóia

# %% [markdown]
# <br>
#
# Uma vez que sei os erros dos nomes e são apenas 3 registros...
# Criei uma coluna duplicada para corrigir!

# %%
# Checa se foi substituido na coluna "Nome Corrigido"
mask = municipio.df_search["municipio_tjsp_corrigido"].str.startswith("Florí")
municipio.df_search[mask]
# Out:
#      id_municipio_ibge  id_municipio_tjsp municipio_tjsp  \
# 186            3516101               6688       Florínia
#
#     municipio_tjsp_corrigido
# 186                 Florínea

# %% [markdown]
# Ajusto a tabela criada

# %%
filename = "municipios"

# Salva
municipio.df_search.to_csv(
    path_or_buf=output_path_tab / f"{filename}.csv",
    index=False,
)

# %% [markdown]
# <br>
#
# ---
#
# ## Detalhes

# %%
# Apenas Exemplo da Função!
municipio.detalhe(id_municipio_tjsp=6504)
# Out:
#    id_municipio_tjsp                         raj municipio_tjsp comarca_tjsp  \
# 0               6504  5ª RAJ Presidente Prudente     Adamantina   Adamantina
# 1               6504  5ª RAJ Presidente Prudente     Adamantina   Adamantina
# 2               6504  5ª RAJ Presidente Prudente     Adamantina   Adamantina
#
#    comarca_sede                                             imovel
# 0             1                                 Fórum I Adamantina
# 1             1           Fórum II Adamantina (Residência Oficial)
# 2             1  Fórum III Adamantina - UAAJ - FAC. ADAM. INTEG...

# %%
municipio.detalhe_batch()

# Results
municipio.df_detalhes.info()
municipio.df_detalhes.head()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1306 entries, 0 to 1309
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id_municipio_tjsp  1306 non-null   int64
#  1   raj                1306 non-null   str
#  2   municipio_tjsp     1306 non-null   str
#  3   comarca_tjsp       1306 non-null   str
#  4   comarca_sede       1306 non-null   int64
#  5   imovel             1306 non-null   str
# dtypes: int64(2), str(4)
# memory usage: 71.4 KB
#    id_municipio_tjsp                         raj municipio_tjsp  comarca_tjsp  \
# 0               6512            10ª RAJ Sorocaba       Alambari  Itapetininga
# 1               6512            10ª RAJ Sorocaba       Alambari  Itapetininga
# 2               6504  5ª RAJ Presidente Prudente     Adamantina    Adamantina
# 3               6504  5ª RAJ Presidente Prudente     Adamantina    Adamantina
# 4               6504  5ª RAJ Presidente Prudente     Adamantina    Adamantina
#
#    comarca_sede                                             imovel
# 0             0  Fórum Itapetininga I - (Desembargador Bernarde...
# 1             0  Fórum Itapetininga II (Criminal) Juiz Paulo Ru...
# 2             1                                 Fórum I Adamantina
# 3             1           Fórum II Adamantina (Residência Oficial)
# 4             1  Fórum III Adamantina - UAAJ - FAC. ADAM. INTEG...

# %%
filename = "municipios_imovel"

# Salva
municipio.df_detalhes.to_csv(
    path_or_buf=output_path_tab / f"{filename}.csv",
    index=False,
)
