# %% [markdown]
# <br>
#
# # Regiões Administrativas Judiciárias (RAJs)
#
# Por meio do _site_ [Quem Somos](https://www.tjsp.jus.br/QuemSomos/QuemSomos/RegioesAdministrativasJudiciarias) obtenho as informações das _Regiões Administrativas Judiciárias_.

# %%
from tjsp_unidades import extract
from tjsp_unidades.paths import output_path_tab

# %%
quem_somos = extract.QuemSomos()

# %% [markdown]
# <br>
#
# Pego os dados das RAJs

# %%
df_raj = quem_somos.rajs

# Results
df_raj.info()
df_raj.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id_raj              10 non-null     int64
#  1   raj_nome            10 non-null     str
#  2   raj_sigla           10 non-null     str
#  3   raj_regiao          10 non-null     str
#  4   juiz_diretor_nome   10 non-null     str
#  5   juiz_diretor_email  10 non-null     str
# dtypes: int64(1), str(5)
# memory usage: 612.0 bytes
#    id_raj                      raj_nome raj_sigla           raj_regiao  \
# 0       1     1ª RAJ - Grande São Paulo    1ª RAJ     Grande São Paulo
# 1       2            2ª RAJ - Araçatuba    2ª RAJ            Araçatuba
# 2       3                3ª RAJ - Bauru    3ª RAJ                Bauru
# 3       4             4ª RAJ - Campinas    4ª RAJ             Campinas
# 4       5  5ª RAJ - Presidente Prudente    5ª RAJ  Presidente Prudente
#
#                    juiz_diretor_nome  juiz_diretor_email
# 0             Fernando Antonio Tasso  daraj1@tjsp.jus.br
# 1  Antonio Fernando Sanches Batagelo  daraj2@tjsp.jus.br
# 2               Gilmar Ferraz Garmes  daraj3@tjsp.jus.br
# 3  Nelson Augusto Bernardes de Souza  daraj4@tjsp.jus.br
# 4          José Wagner Parrão Molina  daraj5@tjsp.jus.br

# %%
df_raj.to_csv(
    path_or_buf=output_path_tab / "rajs.csv",
    index=False,
)
